# %% [markdown]
# <a href="https://colab.research.google.com/github/thizi/project1-front-end-/blob/main/Organisation_fausses_nouvelles_par_theme_plus_abord%C3%A9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
depuis google.colab importer drive
drive.mount  ( '/content/drive' )
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

df = pd.read_excel('/content/drive/MyDrive/cleanData.xlsx')

print(df["thématique"].value_counts().head(5))
# Out:
# thématique
# Santé             66
# Politique         39
# Santé publique    32
# Criminalité       13
# Environnement     10
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

pourcentages.head(5).plot(kind='bar', color='skyblue')

plt.title("Top 5 des thématiques les plus abordées (%)")
plt.ylabel("Pourcentage")
plt.xlabel("Thématique")
plt.tight_layout()
plt.show()
